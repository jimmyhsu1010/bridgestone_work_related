# %%
import pandas as pd
pd.set_option("display.max_rows", None)
from snownlp import SnowNLP
from opencc import OpenCC
import spacy
import spacy_transformers
import zh_core_web_lg
import zh_core_web_trf
from spacy.lang.zh.stop_words import STOP_WORDS
from spacy import displacy

# %%
df = pd.read_excel(r"C:\Users\kc.hsu\Desktop\宏通店.xlsx")

# %%
text = df["review_text"][14]

# %%
s = SnowNLP(text)

# %%
for sentence in s.sentences:
    print(sentence)
# Out:
# 首間旗艦店選在屏東
# 不曉得新竹總部行銷業務部門是什麼操作
# 日本人更厲害
# 還可以相信這種案子
# 不是幫日本人辦畢業旅行
# 就是其他地區店家不願意配合
# 只能說屏東民眾很幸運享受日式高水準服務

# %%
df["review_text"] = df["review_text"].fillna("")

# %%
df["review_text"] = df["review_text"].map(lambda x: OpenCC("tw2sp").convert(x))

# %%
SnowNLP(df["review_text"][0]).sentiments
# Out:
# 0.25719223141012126

# %%
df[df["review_text"] != ""]["review_text"].map(lambda x: SnowNLP(x).sentiments).mean()
# Out:
# 0.736349320424751

# %%
text = u"""俄羅斯侵犯烏克蘭進入16個月，在烏克蘭反攻之際，與俄軍爆發嚴重內訌的俄羅斯傭兵組織瓦格納集團（Wagner Group）發動武裝叛亂，受到全球關注。美國國務卿布林肯（Antony Blinken）25日分析，瓦格納集團發動兵變對俄羅斯總統普丁（Vladimir Putin）帶來空前挑戰，揭露他的領導權威出現新「破口」，這場風波可能要數週或數月時間才會塵埃落定。

布林肯在哥倫比亞廣播公司新聞網（CBS News）談話節目「面對全國」（Face the Nation）提到，瓦格納傭兵集團領導人普里戈津（Yevgeny Prigozhin）週末發動兵變，代表「對普丁權威的直接挑戰」。他又說：「此事引起很大問題，顯示出現真正的破口。」

美國過去24小時一直就此事與歐洲盟國密集諮商，這是美國政府高層首度對俄國局勢這項發展發表公開評論。布林肯和多位美國國會議員25日出現系列電視訪談節目，他們指稱，俄羅斯出亂子已削弱普丁地位，而這可能有助烏克蘭對入侵俄軍發動的反攻，也有益俄羅斯的近鄰，包括波蘭和波羅的海諸國。

布林肯也強調，目前要猜測這場危機對克里姆林宮和烏克蘭戰爭的影響如何，恐怕「還為時過早」。他在美國廣播公司（ABC）的政論節目「本週」（This Week）表示：「我不認為我們已看到最後一幕。」他預期普丁得要在今後數週和數月處理許多問題。

美國官員預期在今後幾天和幾週更了解俄羅斯情勢發展，包括俄羅斯當局在白俄羅斯總統盧卡申科（Alexander Lukashenko）斡旋下與普里戈津達成協議的細節。瓦格納傭兵戰士已依據這項協議返回他們的基地。布林肯指出：「也許普丁不想淪落到必須直接和普里戈津談判的局面。」"""

# %%
nlp = spacy.load("zh_core_web_lg")
# nlp = spacy.blank("en")

# %%
doc = nlp(OpenCC("tw2sp").convert(text))

# %%
for i, token in enumerate(doc):
    print(i, token.text, token.pos_, token.dep_, token.head.text, token.tag_)
# Out:
# 0 俄罗斯 PROPN nsubj 侵犯 NR
# 1 侵犯 VERB ROOT 侵犯 VV
# 2 乌克兰 PROPN dobj 侵犯 NR
# 3 进入 VERB ccomp 侵犯 VV
# 4 16 NUM nummod 月 CD
# 5 个 NUM mark:clf 16 M
# 6 月 NOUN dobj 进入 NN
# 7 ， PUNCT punct 侵犯 PU
# 8 在 ADP case 反攻 P
# 9 乌克兰 PROPN nsubj 反攻 NR
# 10 反攻 VERB nmod:prep 发动 VV
# 11 之际 PART case 反攻 LC
# 12 ， PUNCT punct 发动 PU
# 13 与 ADP case 俄军 P
# 14 俄军 NOUN nmod:prep 爆发 NN
# 15 爆发 VERB acl 集团 VV
# 16 严重 ADJ amod 内讧 JJ
# 17 内讧 NOUN dobj 爆发 NN
# 18 的 PART mark 爆发 DEC
# 19 俄罗斯 PROPN nmod:assmod 组织 NR
# 20 佣兵 NOUN compound:nn 组织 NN
# 21 组织 NOUN compound:nn 集团 NN
# 22 瓦格纳 PROPN compound:nn 集团 NR
# 23 集团 NOUN nsubj 发动 NN
# 24 （ PUNCT punct Group PU
# 25 Wagner PROPN compound:nn Group NR
# 26 Group PROPN parataxis:prnmod 集团 NR
# 27 ） PUNCT punct Group PU
# 28 发动 VERB conj 侵犯 VV
# 29 武装 NOUN compound:nn 叛乱 NN
# 30 叛乱 NOUN dobj 发动 NN
# 31 ， PUNCT punct 发动 PU
# 32 受到 VERB conj 发动 VV
# 33 全球 NOUN compound:nn 关注 NN
# 34 关注 NOUN dobj 受到 NN
# 35 。 PUNCT punct 侵犯 PU
# 36 美国 PROPN nmod:assmod 国务卿 NR
# ...

# %%
for ent in doc.ents:
    print(ent.text, ent.label_)
# Out:
# 俄罗斯 GPE
# 乌克兰 GPE
# 16个月 DATE
# 乌克兰 GPE
# 俄军 ORG
# 俄罗斯佣兵组织瓦格纳集团 ORG
# Wagner Group ORG
# 美国 GPE
# 布尔肯 PERSON
# Antony PERSON
# 25日 DATE
# 瓦格纳集团 ORG
# 俄罗斯 GPE
# 普丁 PERSON
# Vladimir PERSON
# 布尔肯 PERSON
# 哥伦比亚广播公司新闻网 ORG
# CBS News ORG
# 瓦格纳 PERSON
# 普里戈津 PERSON
# Yevgeny Prigozhin ORG
# 周末 DATE
# 普丁 PERSON
# 美国 GPE
# 24小时 TIME
# 欧洲 LOC
# 美国 GPE
# 俄国 GPE
# 布尔肯 PERSON
# 美国国会 ORG
# 25日 DATE
# 俄罗斯 GPE
# 普丁 PERSON
# 乌克兰 GPE
# 俄军 ORG
# 俄罗斯 GPE
# 波兰 GPE
# 波罗的海 LOC
# 布尔肯 PERSON
# 克里姆林宫 ORG
# 乌克兰战争 EVENT
# 美国广播公司 ORG
# 普丁 PERSON
# 数月 DATE
# 美国 GPE
# 今后几天 DATE
# 俄罗斯 GPE
# 俄罗斯 GPE
# 白俄罗斯 GPE
# Alexander Lukashenko PERSON
# 普里 GPE
# 戈津 GPE
# 瓦格纳 PERSON
# 布尔肯 PERSON
# 普丁 PERSON
# 普里 GPE
# 戈津 GPE

# %%
displacy.render(doc, style="ent")
# Out:
# c:\Users\kc.hsu\Python workspace\python_env\lib\site-packages\spacy\displacy\__init__.py:215: UserWarning: [W006] No entities to visualize found in Doc object. If this is surprising to you, make sure the Doc was processed using a model that supports named entity recognition, and check the `doc.ents` property manually if necessary.
#   warnings.warn(Warnings.W006)
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">服务品质超棒内部空间舒适度很棒也有现磨咖啡、点心可以吃喝！柜台人员态度亲切超好的服务品质,！</div></span>

# %%
for sent in doc.sents:
    print(sent.text.strip())
# Out:
# 俄罗斯侵犯乌克兰进入16个月，在乌克兰反攻之际，与俄军爆发严重内讧的俄罗斯佣兵组织瓦格纳集团（Wagner Group）发动武装叛乱，受到全球关注。
# 美国国务卿布尔肯（Antony Blinken）
# 25日分析，瓦格纳集团发动兵变对俄罗斯总统普丁（Vladimir Putin）带来空前挑战，揭露他的领导权威出现新「破口」，这场风波可能要数周或数月时间才会尘埃落定。
# 布尔肯在哥伦比亚广播公司新闻网（CBS News）谈话节目「面对全国」（Face the Nation）提到，瓦格纳佣兵集团领导人普里戈津（Yevgeny Prigozhin）周末发动兵变，代表「对普丁权威的直接挑战」。
# 他又说：「此事引起很大问题，显示出现真正的破口。」
#
# 美国过去24小时一直就此事与欧洲盟国密集咨商，这是美国政府高层首度对俄国局势这项发展发表公开评论。
# 布尔肯和多位美国国会议员25日出现系列电视访谈节目，他们指称，俄罗斯出乱子已削弱普丁地位，而这可能有助乌克兰对入侵俄军发动的反攻，也有益俄罗斯的近邻，包括波兰和波罗的海诸国。
# 布尔肯也强调，目前要猜测这场危机对克里姆林宫和乌克兰战争的影响如何，恐怕「还为时过早」。
# 他在美国广播公司（ABC）的政论节目「本周」（This Week）表示：「我不认为我们已看到最后一幕。」
# 他预期普丁得要在今后数周和数月处理许多问题。
# 美国官员预期在今后几天和几周更了解俄罗斯情势发展，包括俄罗斯当局在白俄罗斯总统卢卡申科（Alexander Lukashenko）斡旋下与普里戈津达成协议的细节。
# 瓦格纳佣兵战士已依据这项协议返回他们的基地。
# 布尔肯指出：「也许普丁不想沦落到必须直接和普里戈津谈判的局面。」

# %%
list(doc.sents)[2]
# Out:
# 25日分析，瓦格纳集团发动兵变对俄罗斯总统普丁（Vladimir Putin）带来空前挑战，揭露他的领导权威出现新「破口」，这场风波可能要数周或数月时间才会尘埃落定。

# %%
displacy.render(doc, style="dep")
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="zh" id="1c67fc50b26d4e87b9f97ede20151254-0" class="displacy" width="53250" height="1012.0" direction="ltr" style="max-width: none; height: 1012.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">俄罗斯</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">侵犯</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
# ...

# %%
ukraine = nlp.vocab["乌克兰"]
russia = nlp.vocab["俄罗斯"]
putin = nlp.vocab["普丁"]

# %%
ukraine.similarity(russia)
# Out:
# 0.833292543888092

# %%
doc = nlp(df["review_text"][11])

# %%
tokens = [token.text for token in doc]

# %%
tokens = [t for t in tokens if t not in stopwords]

# %%
result = "".join(tokens)
