# %%
import market_survey as ms
import pandas as pd

# %%
conti = ms.get_conti_shops()
michelin = ms.get_michelin_shops()

# %%
with pd.ExcelWriter(r"D:\kc.hsu\OneDrive - Bridgestone\行銷推廣\Michelin經銷店數\20230718_competitor_shops.xlsx") as writer:
    conti.to_excel(writer, sheet_name="continental", index=False)
    michelin.to_excel(writer, sheet_name="michelin", index=False)

# %%
conti
# Out:
#      shop_type                   name        phone area city  \
# 0    BestDrive      BestDrive百世德 佳連輪胎   03-3694316   北區  桃園市
# 1    BestDrive      BestDrive百世德 鉅鑫輪胎   03-3563432   北區  桃園市
# 2    BestDrive      BestDrive百世德 弘旺輪胎   03-3223962   北區  桃園市
# 3    BestDrive  BestDrive百世德 百樂達輪胎文一店   03-3271011   北區  桃園市
# 4          一般店                   昇旺輪胎   03-2125000   北區  桃園市
# ..         ...                    ...          ...  ...  ...
# 134        一般店                   泰順輪胎   05-5350428   中區  雲林縣
# 135        一般店                   建泰汽車   04-7517500   中區  彰化縣
# 136        一般店                   順億輪胎   037-867701   中區  苗栗縣
# 137        一般店                   清芳保修  05-2307535    南區  嘉義縣
# 138        一般店                  詮智輪胎行   05-5843899   中區  雲林縣
#
#                          address                                 location
# 0                  桃園區中山里中山路732號  {'lat': 24.9914545, 'lng': 121.2928604}
# 1                   大興西路一段112號1樓   {'lat': 25.0149467, 'lng': 121.305707}
# ...

# %%
michelin
# Out:
#        id                sname                 name county district  \
# 0    5269  MICHELIN米其林輪胎中心-上全店  MICHELIN米其林輪胎中心-上全店    台中市       北區
# 1    4380  MICHELIN米其林輪胎中心-上好店  MICHELIN米其林輪胎中心-上好店    桃園市      中壢區
# 2    4379  MICHELIN米其林輪胎中心-上傑店  MICHELIN米其林輪胎中心-上傑店    嘉義市       西區
# 3    5328  MICHELIN米其林輪胎中心-上翔店  MICHELIN米其林輪胎中心-上翔店    台中市      南屯區
# 4    4400  MICHELIN米其林輪胎中心-千玉店  MICHELIN米其林輪胎中心-千玉店    花蓮縣      玉里鎮
# ..    ...                  ...                  ...    ...      ...
# 547  5393               鉦盛有限公司               鉦盛有限公司    新北市      樹林區
# 548  4470                鉦豐輪胎行                鉦豐輪胎行    台南市      佳里區
# 549  5220             鋐祥輪胎有限公司             鋐祥輪胎有限公司    桃園市      蘆竹區
# 550  5223                燁都輪胎行                燁都輪胎行    高雄市      前鎮區
# 551  5252               驊慶有限公司               驊慶有限公司    新北市      汐止區
#
#          address          tel close_time  \
# 0       進化北路146號  04-22318942          日
# 1      中北路二段360號   03-4583469          日
# ...
