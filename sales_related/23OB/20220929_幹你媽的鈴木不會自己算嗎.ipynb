# %%
import pandas as pd
import tkinter as tk
from tkinter import filedialog
pd.set_option("display.max_columns", None)
pd.set_option("mode.chained_assignment", None)

# %%
df = pd.read_clipboard()

# %%
df.columns = ['製品編碼', '產地', '小通路', "大通路", 'TBR Premium', '規格', '花紋',
       '分公司銷售量 CY 1月', '分公司銷售量 CY 2月', '分公司銷售量 CY 3月', '分公司銷售量 CY 4月',
       '分公司銷售量 CY 5月', '分公司銷售量 CY 6月', '分公司銷售量 CY 7月', '分公司銷售量 CY 8月',
       '分公司銷售量 CY 9月', '分公司銷售量 CY 10月', '分公司銷售量 CY 11月', '分公司銷售量 CY 12月',
       '分公司銷售量 Y1 1月', '分公司銷售量 Y1 2月', '分公司銷售量 Y1 3月', '分公司銷售量 Y1 4月',
       '分公司銷售量 Y1 5月', '分公司銷售量 Y1 6月', '分公司銷售量 Y1 7月', '分公司銷售量 Y1 8月',
       '分公司銷售量 Y1 9月', '分公司銷售量 Y1 10月', '分公司銷售量 Y1 11月', '分公司銷售量 Y1 12月', '分公司銷售量Y2', '分公司銷售量Y3',
       '銷售定價（分月度） CY 1月', '銷售定價（分月度） CY 2月', '銷售定價（分月度） CY 3月',
       '銷售定價（分月度） CY 4月', '銷售定價（分月度） CY 5月', '銷售定價（分月度） CY 6月',
       '銷售定價（分月度） CY 7月', '銷售定價（分月度） CY 8月', '銷售定價（分月度） CY 9月',
       '銷售定價（分月度） CY 10月', '銷售定價（分月度） CY 11月', '銷售定價（分月度） CY 12月',
       '銷售定價（分月度） Y+1 1月', '銷售定價（分月度） Y+1 2月', '銷售定價（分月度） Y+1 3月',
       '銷售定價（分月度） Y+1 4月', '銷售定價（分月度） Y+1 5月', '銷售定價（分月度） Y+1 6月',
       '銷售定價（分月度） Y+1 7月', '銷售定價（分月度） Y+1 8月', '銷售定價（分月度） Y+1 9月',
       '銷售定價（分月度） Y+1 10月', '銷售定價（分月度） Y+1 11月', '銷售定價（分月度） Y+1 12月', '銷售定價（分月度） Y+2', '銷售定價（分月度） Y+3',
       '折扣率（分月度） CY 1月', '折扣率（分月度） CY 2月', '折扣率（分月度） CY 3月', '折扣率（分月度） CY 4月',
       '折扣率（分月度） CY 5月', '折扣率（分月度） CY 6月', '折扣率（分月度） CY 7月', '折扣率（分月度） CY 8月',
       '折扣率（分月度） CY 9月', '折扣率（分月度） CY 10月', '折扣率（分月度） CY 11月',
       '折扣率（分月度） CY 12月', '折扣率（分月度） Y+1 1月', '折扣率（分月度） Y+1 2月',
       '折扣率（分月度） Y+1 3月', '折扣率（分月度） Y+1 4月', '折扣率（分月度） Y+1 5月',
       '折扣率（分月度） Y+1 6月', '折扣率（分月度） Y+1 7月', '折扣率（分月度） Y+1 8月',
       '折扣率（分月度） Y+1 9月', '折扣率（分月度） Y+1 10月', '折扣率（分月度） Y+1 11月',
       '折扣率（分月度） Y+1 12月', '折扣率（分月度） Y+2', '折扣率（分月度） Y+3']

# %%
volume = df[['製品編碼', '產地', '小通路', "大通路", 'TBR Premium', '規格', '花紋',
       '分公司銷售量 CY 1月', '分公司銷售量 CY 2月', '分公司銷售量 CY 3月', '分公司銷售量 CY 4月',
       '分公司銷售量 CY 5月', '分公司銷售量 CY 6月', '分公司銷售量 CY 7月', '分公司銷售量 CY 8月',
       '分公司銷售量 CY 9月', '分公司銷售量 CY 10月', '分公司銷售量 CY 11月', '分公司銷售量 CY 12月',
       '分公司銷售量 Y1 1月', '分公司銷售量 Y1 2月', '分公司銷售量 Y1 3月', '分公司銷售量 Y1 4月',
       '分公司銷售量 Y1 5月', '分公司銷售量 Y1 6月', '分公司銷售量 Y1 7月', '分公司銷售量 Y1 8月',
       '分公司銷售量 Y1 9月', '分公司銷售量 Y1 10月', '分公司銷售量 Y1 11月', '分公司銷售量 Y1 12月', '分公司銷售量Y2', '分公司銷售量Y3']].set_index(['製品編碼', '產地', '小通路', "大通路", 'TBR Premium', '規格', '花紋']).stack().reset_index()

# %%
volume = df[['製品編碼', '產地', '小通路', "大通路", 'TBR Premium', '規格', '花紋',
       '分公司銷售量 CY 1月', '分公司銷售量 CY 2月', '分公司銷售量 CY 3月', '分公司銷售量 CY 4月',
       '分公司銷售量 CY 5月', '分公司銷售量 CY 6月', '分公司銷售量 CY 7月', '分公司銷售量 CY 8月',
       '分公司銷售量 CY 9月', '分公司銷售量 CY 10月', '分公司銷售量 CY 11月', '分公司銷售量 CY 12月',
       '分公司銷售量 Y1 1月', '分公司銷售量 Y1 2月', '分公司銷售量 Y1 3月', '分公司銷售量 Y1 4月',
       '分公司銷售量 Y1 5月', '分公司銷售量 Y1 6月', '分公司銷售量 Y1 7月', '分公司銷售量 Y1 8月',
       '分公司銷售量 Y1 9月', '分公司銷售量 Y1 10月', '分公司銷售量 Y1 11月', '分公司銷售量 Y1 12月', '分公司銷售量Y2', '分公司銷售量Y3']].set_index(['製品編碼', '產地', '小通路', "大通路", 'TBR Premium', '規格', '花紋']).stack().reset_index()

# %%
volume.columns = ['製品編碼', '產地', '小通路', "大通路", 'TBR Premium', '規格', '花紋', '年月', '數量']

# %%
year_key = ['分公司銷售量 CY 1月', '分公司銷售量 CY 2月', '分公司銷售量 CY 3月', '分公司銷售量 CY 4月',
       '分公司銷售量 CY 5月', '分公司銷售量 CY 6月', '分公司銷售量 CY 7月', '分公司銷售量 CY 8月',
       '分公司銷售量 CY 9月', '分公司銷售量 CY 10月', '分公司銷售量 CY 11月', '分公司銷售量 CY 12月',
       '分公司銷售量 Y1 1月', '分公司銷售量 Y1 2月', '分公司銷售量 Y1 3月', '分公司銷售量 Y1 4月',
       '分公司銷售量 Y1 5月', '分公司銷售量 Y1 6月', '分公司銷售量 Y1 7月', '分公司銷售量 Y1 8月',
       '分公司銷售量 Y1 9月', '分公司銷售量 Y1 10月', '分公司銷售量 Y1 11月', '分公司銷售量 Y1 12月', '分公司銷售量Y2', '分公司銷售量Y3']
year_values = ["2022/01", "2022/02", "2022/03", "2022/04", "2022/05", "2022/06", "2022/07", "2022/08", "2022/09", "2022/10", "2022/11", "2022/12", "2023/01", "2023/02", "2023/03", "2023/04", "2023/05", "2023/06", "2023/07", "2023/08", "2023/09", "2023/10", "2023/11", "2023/12", "2024/全年", "2025/全年"]
year_dict = dict(zip(year_key, year_values))

# %%
volume["新年月"] = volume["年月"].map(year_dict)

# %%
year_mon = volume["新年月"].str.split("/", expand=True)

# %%
year_mon.columns = ["年", "月"]

# %%
volume_result = pd.concat([volume,year_mon], axis=1)

# %%
volume_result
# Out:
#            製品編碼    產地      小通路      大通路  TBR Premium           規格    花紋  \
# 0     300091160  BTMT  FLT-REP  FLT-REP  TBR premium  295/80R22.5  UAP1
# 1     300091160  BTMT  FLT-REP  FLT-REP  TBR premium  295/80R22.5  UAP1
# 2     300091160  BTMT  FLT-REP  FLT-REP  TBR premium  295/80R22.5  UAP1
# 3     300091160  BTMT  FLT-REP  FLT-REP  TBR premium  295/80R22.5  UAP1
# 4     300091160  BTMT  FLT-REP  FLT-REP  TBR premium  295/80R22.5  UAP1
# ...         ...   ...      ...      ...          ...          ...   ...
# 6859  300122263  BTMT      FMC     BSSC  TBR premium  225/90R17.5  R154
# 6860  300122263  BTMT      FMC     BSSC  TBR premium  225/90R17.5  R154
# 6861  300122263  BTMT      FMC     BSSC  TBR premium  225/90R17.5  R154
# 6862  300122263  BTMT      FMC     BSSC  TBR premium  225/90R17.5  R154
# 6863  300122263  BTMT      FMC     BSSC  TBR premium  225/90R17.5  R154
#
#                  年月  數量      新年月     年   月
# 0      分公司銷售量 CY 1月   0  2022/01  2022  01
# 1      分公司銷售量 CY 2月   0  2022/02  2022  02
# 2      分公司銷售量 CY 3月   0  2022/03  2022  03
# 3      分公司銷售量 CY 4月   0  2022/04  2022  04
# 4      分公司銷售量 CY 5月   0  2022/05  2022  05
# ...             ...  ..      ...   ...  ..
# 6859  分公司銷售量 Y1 10月   0  2023/10  2023  10
# 6860  分公司銷售量 Y1 11月   0  2023/11  2023  11
# 6861  分公司銷售量 Y1 12月   0  2023/12  2023  12
# 6862       分公司銷售量Y2   0  2024/全年  2024  全年
# 6863       分公司銷售量Y3   0  2025/全年  2025  全年
#
# [6864 rows x 12 columns]

# %%
volume_result = volume_result[['製品編碼', '產地', '小通路', '大通路', 'TBR Premium', '規格', '花紋', '數量', '新年月', '年', '月']]

# %%
list_price = df[['製品編碼', '產地', '小通路', "大通路", 'TBR Premium', '規格', '花紋', '銷售定價（分月度） CY 1月', '銷售定價（分月度） CY 2月', '銷售定價（分月度） CY 3月',
       '銷售定價（分月度） CY 4月', '銷售定價（分月度） CY 5月', '銷售定價（分月度） CY 6月',
       '銷售定價（分月度） CY 7月', '銷售定價（分月度） CY 8月', '銷售定價（分月度） CY 9月',
       '銷售定價（分月度） CY 10月', '銷售定價（分月度） CY 11月', '銷售定價（分月度） CY 12月',
       '銷售定價（分月度） Y+1 1月', '銷售定價（分月度） Y+1 2月', '銷售定價（分月度） Y+1 3月',
       '銷售定價（分月度） Y+1 4月', '銷售定價（分月度） Y+1 5月', '銷售定價（分月度） Y+1 6月',
       '銷售定價（分月度） Y+1 7月', '銷售定價（分月度） Y+1 8月', '銷售定價（分月度） Y+1 9月',
       '銷售定價（分月度） Y+1 10月', '銷售定價（分月度） Y+1 11月', '銷售定價（分月度） Y+1 12月', '銷售定價（分月度） Y+2', '銷售定價（分月度） Y+3']].set_index(['製品編碼', '產地', '小通路', "大通路", 'TBR Premium', '規格', '花紋']).stack().reset_index()

# %%
list_price.columns = ['製品編碼', '產地', '小通路', "大通路", 'TBR Premium', '規格', '花紋', '年月', "未稅牌價"]

# %%
year_key = ['銷售定價（分月度） CY 1月', '銷售定價（分月度） CY 2月', '銷售定價（分月度） CY 3月',
       '銷售定價（分月度） CY 4月', '銷售定價（分月度） CY 5月', '銷售定價（分月度） CY 6月',
       '銷售定價（分月度） CY 7月', '銷售定價（分月度） CY 8月', '銷售定價（分月度） CY 9月',
       '銷售定價（分月度） CY 10月', '銷售定價（分月度） CY 11月', '銷售定價（分月度） CY 12月',
       '銷售定價（分月度） Y+1 1月', '銷售定價（分月度） Y+1 2月', '銷售定價（分月度） Y+1 3月',
       '銷售定價（分月度） Y+1 4月', '銷售定價（分月度） Y+1 5月', '銷售定價（分月度） Y+1 6月',
       '銷售定價（分月度） Y+1 7月', '銷售定價（分月度） Y+1 8月', '銷售定價（分月度） Y+1 9月',
       '銷售定價（分月度） Y+1 10月', '銷售定價（分月度） Y+1 11月', '銷售定價（分月度） Y+1 12月', '銷售定價（分月度） Y+2', '銷售定價（分月度） Y+3']
year_values = ["2022/01", "2022/02", "2022/03", "2022/04", "2022/05", "2022/06", "2022/07", "2022/08", "2022/09", "2022/10", "2022/11", "2022/12", "2023/01", "2023/02", "2023/03", "2023/04", "2023/05", "2023/06", "2023/07", "2023/08", "2023/09", "2023/10", "2023/11", "2023/12", "2024/全年", "2025/全年"]
year_dict = dict(zip(year_key, year_values))

# %%
list_price["新年月"] = list_price["年月"].map(year_dict)
year_mon = list_price["新年月"].str.split("/", expand=True)
year_mon.columns = ["年", "月"]
list_price_result = pd.concat([list_price,year_mon], axis=1)
list_price_result
# Out:
#            製品編碼    產地      小通路      大通路  TBR Premium           規格    花紋  \
# 0     300091160  BTMT  FLT-REP  FLT-REP  TBR premium  295/80R22.5  UAP1
# 1     300091160  BTMT  FLT-REP  FLT-REP  TBR premium  295/80R22.5  UAP1
# 2     300091160  BTMT  FLT-REP  FLT-REP  TBR premium  295/80R22.5  UAP1
# 3     300091160  BTMT  FLT-REP  FLT-REP  TBR premium  295/80R22.5  UAP1
# 4     300091160  BTMT  FLT-REP  FLT-REP  TBR premium  295/80R22.5  UAP1
# ...         ...   ...      ...      ...          ...          ...   ...
# 6859  300122263  BTMT      FMC     BSSC  TBR premium  225/90R17.5  R154
# 6860  300122263  BTMT      FMC     BSSC  TBR premium  225/90R17.5  R154
# 6861  300122263  BTMT      FMC     BSSC  TBR premium  225/90R17.5  R154
# 6862  300122263  BTMT      FMC     BSSC  TBR premium  225/90R17.5  R154
# 6863  300122263  BTMT      FMC     BSSC  TBR premium  225/90R17.5  R154
#
#                      年月  未稅牌價      新年月     年   月
# 0       銷售定價（分月度） CY 1月     0  2022/01  2022  01
# 1       銷售定價（分月度） CY 2月     0  2022/02  2022  02
# 2       銷售定價（分月度） CY 3月     0  2022/03  2022  03
# 3       銷售定價（分月度） CY 4月     0  2022/04  2022  04
# 4       銷售定價（分月度） CY 5月     0  2022/05  2022  05
# ...                 ...   ...      ...   ...  ..
# 6859  銷售定價（分月度） Y+1 10月     0  2023/10  2023  10
# 6860  銷售定價（分月度） Y+1 11月     0  2023/11  2023  11
# 6861  銷售定價（分月度） Y+1 12月     0  2023/12  2023  12
# 6862      銷售定價（分月度） Y+2  6599  2024/全年  2024  全年
# 6863      銷售定價（分月度） Y+3  6731  2025/全年  2025  全年
#
# [6864 rows x 12 columns]

# %%
list_price_result = list_price_result[['製品編碼', '產地', '小通路', '大通路', 'TBR Premium', '規格', '花紋', '未稅牌價', '新年月', '年', '月']]

# %%
discount = df[['製品編碼', '產地', '小通路', "大通路", 'TBR Premium', '規格', '花紋', '折扣率（分月度） CY 1月', '折扣率（分月度） CY 2月', '折扣率（分月度） CY 3月', '折扣率（分月度） CY 4月',
       '折扣率（分月度） CY 5月', '折扣率（分月度） CY 6月', '折扣率（分月度） CY 7月', '折扣率（分月度） CY 8月',
       '折扣率（分月度） CY 9月', '折扣率（分月度） CY 10月', '折扣率（分月度） CY 11月',
       '折扣率（分月度） CY 12月', '折扣率（分月度） Y+1 1月', '折扣率（分月度） Y+1 2月',
       '折扣率（分月度） Y+1 3月', '折扣率（分月度） Y+1 4月', '折扣率（分月度） Y+1 5月',
       '折扣率（分月度） Y+1 6月', '折扣率（分月度） Y+1 7月', '折扣率（分月度） Y+1 8月',
       '折扣率（分月度） Y+1 9月', '折扣率（分月度） Y+1 10月', '折扣率（分月度） Y+1 11月',
       '折扣率（分月度） Y+1 12月', '折扣率（分月度） Y+2', '折扣率（分月度） Y+3']].set_index(['製品編碼', '產地', '小通路', "大通路", 'TBR Premium', '規格', '花紋']).stack().reset_index()

# %%
discount
# Out:
#            製品編碼    產地      小通路      大通路  TBR Premium           規格    花紋  \
# 0     300091160  BTMT  FLT-REP  FLT-REP  TBR premium  295/80R22.5  UAP1
# 1     300091160  BTMT  FLT-REP  FLT-REP  TBR premium  295/80R22.5  UAP1
# 2     300091160  BTMT  FLT-REP  FLT-REP  TBR premium  295/80R22.5  UAP1
# 3     300091160  BTMT  FLT-REP  FLT-REP  TBR premium  295/80R22.5  UAP1
# 4     300091160  BTMT  FLT-REP  FLT-REP  TBR premium  295/80R22.5  UAP1
# ...         ...   ...      ...      ...          ...          ...   ...
# 6859  300122263  BTMT      FMC     BSSC  TBR premium  225/90R17.5  R154
# 6860  300122263  BTMT      FMC     BSSC  TBR premium  225/90R17.5  R154
# 6861  300122263  BTMT      FMC     BSSC  TBR premium  225/90R17.5  R154
# 6862  300122263  BTMT      FMC     BSSC  TBR premium  225/90R17.5  R154
# 6863  300122263  BTMT      FMC     BSSC  TBR premium  225/90R17.5  R154
#
#                level_7      0
# 0       折扣率（分月度） CY 1月  0.000
# 1       折扣率（分月度） CY 2月  0.000
# 2       折扣率（分月度） CY 3月  0.000
# 3       折扣率（分月度） CY 4月  0.000
# 4       折扣率（分月度） CY 5月  0.000
# ...                ...    ...
# 6859  折扣率（分月度） Y+1 10月  0.000
# 6860  折扣率（分月度） Y+1 11月  0.000
# 6861  折扣率（分月度） Y+1 12月  0.000
# 6862      折扣率（分月度） Y+2  0.065
# 6863      折扣率（分月度） Y+3  0.065
#
# [6864 rows x 9 columns]

# %%
discount.columns = ['製品編碼', '產地', '小通路', "大通路", 'TBR Premium', '規格', '花紋', '年月', "折扣率"]
year_key = ['折扣率（分月度） CY 1月', '折扣率（分月度） CY 2月', '折扣率（分月度） CY 3月', '折扣率（分月度） CY 4月',
       '折扣率（分月度） CY 5月', '折扣率（分月度） CY 6月', '折扣率（分月度） CY 7月', '折扣率（分月度） CY 8月',
       '折扣率（分月度） CY 9月', '折扣率（分月度） CY 10月', '折扣率（分月度） CY 11月',
       '折扣率（分月度） CY 12月', '折扣率（分月度） Y+1 1月', '折扣率（分月度） Y+1 2月',
       '折扣率（分月度） Y+1 3月', '折扣率（分月度） Y+1 4月', '折扣率（分月度） Y+1 5月',
       '折扣率（分月度） Y+1 6月', '折扣率（分月度） Y+1 7月', '折扣率（分月度） Y+1 8月',
       '折扣率（分月度） Y+1 9月', '折扣率（分月度） Y+1 10月', '折扣率（分月度） Y+1 11月',
       '折扣率（分月度） Y+1 12月', '折扣率（分月度） Y+2', '折扣率（分月度） Y+3']
year_values = ["2022/01", "2022/02", "2022/03", "2022/04", "2022/05", "2022/06", "2022/07", "2022/08", "2022/09", "2022/10", "2022/11", "2022/12", "2023/01", "2023/02", "2023/03", "2023/04", "2023/05", "2023/06", "2023/07", "2023/08", "2023/09", "2023/10", "2023/11", "2023/12", "2024/全年", "2025/全年"]
year_dict = dict(zip(year_key, year_values))
discount["新年月"] = discount["年月"].map(year_dict)
year_mon = discount["新年月"].str.split("/", expand=True)
year_mon.columns = ["年", "月"]
discount_result = pd.concat([discount,year_mon], axis=1)
discount_result
# Out:
#            製品編碼    產地      小通路      大通路  TBR Premium           規格    花紋  \
# 0     300091160  BTMT  FLT-REP  FLT-REP  TBR premium  295/80R22.5  UAP1
# 1     300091160  BTMT  FLT-REP  FLT-REP  TBR premium  295/80R22.5  UAP1
# 2     300091160  BTMT  FLT-REP  FLT-REP  TBR premium  295/80R22.5  UAP1
# 3     300091160  BTMT  FLT-REP  FLT-REP  TBR premium  295/80R22.5  UAP1
# 4     300091160  BTMT  FLT-REP  FLT-REP  TBR premium  295/80R22.5  UAP1
# ...         ...   ...      ...      ...          ...          ...   ...
# 6859  300122263  BTMT      FMC     BSSC  TBR premium  225/90R17.5  R154
# 6860  300122263  BTMT      FMC     BSSC  TBR premium  225/90R17.5  R154
# 6861  300122263  BTMT      FMC     BSSC  TBR premium  225/90R17.5  R154
# 6862  300122263  BTMT      FMC     BSSC  TBR premium  225/90R17.5  R154
# 6863  300122263  BTMT      FMC     BSSC  TBR premium  225/90R17.5  R154
#
#                     年月    折扣率      新年月     年   月
# 0       折扣率（分月度） CY 1月  0.000  2022/01  2022  01
# 1       折扣率（分月度） CY 2月  0.000  2022/02  2022  02
# 2       折扣率（分月度） CY 3月  0.000  2022/03  2022  03
# 3       折扣率（分月度） CY 4月  0.000  2022/04  2022  04
# 4       折扣率（分月度） CY 5月  0.000  2022/05  2022  05
# ...                ...    ...      ...   ...  ..
# 6859  折扣率（分月度） Y+1 10月  0.000  2023/10  2023  10
# 6860  折扣率（分月度） Y+1 11月  0.000  2023/11  2023  11
# 6861  折扣率（分月度） Y+1 12月  0.000  2023/12  2023  12
# 6862      折扣率（分月度） Y+2  0.065  2024/全年  2024  全年
# 6863      折扣率（分月度） Y+3  0.065  2025/全年  2025  全年
#
# [6864 rows x 12 columns]

# %%
discount_result = discount_result[['製品編碼', '產地', '小通路', '大通路', 'TBR Premium', '規格', '花紋', '折扣率', '新年月', '年', '月']]

# %%
volume_price = pd.merge(volume_result, list_price_result, on=['製品編碼', '產地', '小通路', '大通路', 'TBR Premium', '規格', '花紋', '新年月', '年', '月'])

# %%
final_result = pd.merge(volume_price, discount_result, on=['製品編碼', '產地', '小通路', '大通路', 'TBR Premium', '規格', '花紋', '新年月', '年', '月'])

# %%
final_result
# Out:
#            製品編碼    產地      小通路      大通路  TBR Premium           規格    花紋  數量  \
# 0     300091160  BTMT  FLT-REP  FLT-REP  TBR premium  295/80R22.5  UAP1   0
# 1     300091160  BTMT  FLT-REP  FLT-REP  TBR premium  295/80R22.5  UAP1   0
# 2     300091160  BTMT  FLT-REP  FLT-REP  TBR premium  295/80R22.5  UAP1   0
# 3     300091160  BTMT  FLT-REP  FLT-REP  TBR premium  295/80R22.5  UAP1   0
# 4     300091160  BTMT  FLT-REP  FLT-REP  TBR premium  295/80R22.5  UAP1   0
# ...         ...   ...      ...      ...          ...          ...   ...  ..
# 7015  300122263  BTMT      FMC     BSSC  TBR premium  225/90R17.5  R154   0
# 7016  300122263  BTMT      FMC     BSSC  TBR premium  225/90R17.5  R154   0
# 7017  300122263  BTMT      FMC     BSSC  TBR premium  225/90R17.5  R154   0
# 7018  300122263  BTMT      FMC     BSSC  TBR premium  225/90R17.5  R154   0
# 7019  300122263  BTMT      FMC     BSSC  TBR premium  225/90R17.5  R154   0
#
#           新年月     年   月  未稅牌價    折扣率
# 0     2022/01  2022  01     0  0.000
# 1     2022/02  2022  02     0  0.000
# 2     2022/03  2022  03     0  0.000
# 3     2022/04  2022  04     0  0.000
# 4     2022/05  2022  05     0  0.000
# ...       ...   ...  ..   ...    ...
# 7015  2023/10  2023  10     0  0.000
# 7016  2023/11  2023  11     0  0.000
# 7017  2023/12  2023  12     0  0.000
# 7018  2024/全年  2024  全年  6599  0.065
# 7019  2025/全年  2025  全年  6731  0.065
#
# [7020 rows x 13 columns]

# %%
final_result.to_excel(r"D:\kc.hsu\OneDrive - Bridgestone\OB\23OB\20221121_23OB_原始數據.xlsx", index=False)
